# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a simple DataFrame
data = {'Year': [2018, 2019, 2020, 2021, 2022],
        'Sales': [1200, 1500, 1800, 2000, 2500]}
df = pd.DataFrame(data)

# Plot Sales data
plt.figure(figsize=(8,5))
plt.plot(df['Year'], df['Sales'], marker='o', color='b', label='Sales')
plt.title('Sales Over Years')
plt.xlabel('Year')
plt.ylabel('Sales (in USD)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pandas DataFrame created and basic plot generated!

# %% [markdown]
# # Visualization with Matplotlib and Pandas
# In this notebook, we will explore how to use **Pandas** for data manipulation and **Matplotlib** for visualizing the data.
# First, let's create a simple dataset using Pandas and plot it using Matplotlib.
#
# ### Step 1: Create a DataFrame
# We'll create a DataFrame that contains sales data for different years.
#
# ### Step 2: Plot the Data
# We will use Matplotlib to visualize the sales data over the years with a line plot.
